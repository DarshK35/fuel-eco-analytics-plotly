# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/data_18_v4.csv")

# %%
df.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 1  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 2  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 4  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  3.0        20       28       23                     5
# 1                  3.0        19       27       22                     4
# 2                  3.0        23       33       27                     6
# 3                  3.0        20       32       24                     5
# 4                  3.0        21       30       24                     5
#
#   smartway
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832 entries, 0 to 831
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 832 non-null    object
#  1   displ                 832 non-null    float64
#  2   cyl                   832 non-null    int64
#  3   trans                 832 non-null    object
#  4   drive                 832 non-null    object
#  5   fuel                  832 non-null    object
#  6   veh_class             832 non-null    object
#  7   air_pollution_score   832 non-null    float64
#  8   city_mpg              832 non-null    int64
#  9   hwy_mpg               832 non-null    int64
#  10  cmb_mpg               832 non-null    int64
#  11  greenhouse_gas_score  832 non-null    int64
#  12  smartway              832 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 84.6+ KB

# %%
fig = px.sunburst(df, path=['fuel', 'veh_class'], values='air_pollution_score')
fig.update_layout(title_text='Comparison of what fuel types result in a higher air pollution score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d41dbc29-8227-4b78-8457-db48639958df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d41dbc29-8227-4b78-8457-db48639958df")) {                    Plotly.newPlot(                        "d41dbc29-8227-4b78-8457-db48639958df",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eair_pollution_score=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Electricity\u002flarge car","Ethanol\u002flarge car","Gas\u002flarge car","Gasoline\u002flarge car","Diesel\u002fmidsize car","Electricity\u002fmidsize car","Gasoline\u002fmidsize car","Gasoline\u002fminivan","Diesel\u002fpickup","Ethanol\u002fpickup","Gas\u002fpickup","Gasoline\u002fpickup","Diesel\u002fsmall SUV","Electricity\u002fsmall SUV","Ethanol\u002fsmall SUV","Gas\u002fsmall SUV","Gasoline\u002fsmall SUV","Diesel\u002fsmall car","Electricity\u002fsmall car","Ethanol\u002fsmall car","Gas\u002fsmall car","Gasoline\u002fsmall car","Gasoline\u002fspecial purpose","Electricity\u002fstandard SUV","Ethanol\u002fstandard SUV","Gas\u002fstandard SUV","Gasoline\u002fstandard SUV","Gasoline\u002fstation wagon","Diesel","Electricity","Ethanol","Gas","Gasoline"],"labels":["large car","large car","large car","large car","midsize car","midsize car","midsize car","minivan","pickup","pickup","pickup","pickup","small SUV","small SUV","small SUV","small SUV","small SUV","small car","small car","small car","small car","small car","special purpose","standard SUV","standard SUV","standard SUV","standard SUV","station wagon","Diesel","Electricity","Ethanol","Gas","Gasoline"],"name":"","parents":["Electricity","Ethanol","Gas","Gasoline","Diesel","Electricity","Gasoline","Gasoline","Diesel","Ethanol","Gas","Gasoline","Diesel","Electricity","Ethanol","Gas","Gasoline","Diesel","Electricity","Ethanol","Gas","Gasoline","Gasoline","Electricity","Ethanol","Gas","Gasoline","Gasoline","","","","",""],"values":[3.0,17.0,17.0,311.0,8.0,17.0,607.0,15.0,15.0,31.0,31.0,235.0,14.0,7.0,11.0,11.0,421.0,8.0,28.0,5.0,5.0,1026.0,34.0,7.0,32.0,32.0,217.0,148.0,45.0,62.0,96.0,96.0,3014.0],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555 ...

# %% [markdown]
# **Here, a sunburst chart is being used to display which fuel type contributes the most to air pollution and which fuel types different cars use.**
# The reason for showing this visualization is to inform the user about which cars are the most harmful to the environment and urges them to not buy these car types.

# %%
sns.pairplot(df[['city_mpg', 'hwy_mpg', 'cmb_mpg']])
plt.show()

# %% [markdown]
# **The purpose of using a pair plot is to show how efficient the vehicle is in terms of miles-per-gallon of fuel across different terrains: City, Highway and combined road type**
# This type of pair plot has been used to see if a vehicle that is performing in a certain way on a particular terrain type will have the same proportional efficiency on another terrain.
# So as we can see, there is a fairly linear relationship that is being noticed between the mpg on different terrains and so **a closely-accurate estimate can be made to see how a car will perform on different terrain types if we already know how it performs on one terrain.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='trans', y='air_pollution_score', data=df, palette='viridis')
plt.xlabel('Transmission Type')
plt.ylabel('Air Pollution Score')
plt.title('Air Pollution Score by Transmission Type')
plt.xticks(rotation=45)
plt.show()
